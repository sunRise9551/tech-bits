# %% [markdown]
# # MobileNet V2

# %% [markdown]
# - MobileNet V2: Inverted Residuals and Linear Bottlenecks
# - https://arxiv.org/pdf/1801.04381

# %% [markdown]
# ## Highlights

# %% [markdown]
# - Inverted Residuals
# - Linear Bottlenecks

# %% [markdown]
# ## Inverted Residuals vs Residuals

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ReLU6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
