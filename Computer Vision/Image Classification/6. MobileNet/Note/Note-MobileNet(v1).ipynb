# %% [markdown]
# # MobileNet (v1)

# %% [markdown]
# - Efficient Convolutional Neural Networks for Mobile Vision Applications
# - https://arxiv.org/pdf/1704.04861

# %% [markdown]
# ## Highlights

# %% [markdown]
# - Depthwise Convolution (greatly reduces computational complexity and parameter quantity)
# - Increase hyperparameters α, β

# %% [markdown]
# ## Traditional Conv vs Depthwise Conv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Depthwise Separable Conv

# %% [markdown]
# - Depthwise + Pointwise

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## MobileNet Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## MobileNet (v1) Problem

# %% [markdown]
# - A lot of useless DW layer
# - Wil be further optimize in MobileNet(v2)
